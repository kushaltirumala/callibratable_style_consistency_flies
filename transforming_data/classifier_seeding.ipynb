# %%
import numpy as np
from keras.models import Sequential
from keras.layers import Dense
from keras.layers import Conv1D
from keras.layers import LSTM
from keras.layers import MaxPooling1D
from keras.layers import Dropout
from keras.layers import SpatialDropout1D
from keras.layers.embeddings import Embedding
from keras.preprocessing import sequence
from sklearn.model_selection import train_test_split
from tensorflow import set_random_seed
from numpy.random import seed
from sklearn.model_selection import KFold

# %%
X = np.load('compressed_final_data/copulation_segmented_train.npz')['data']
y = np.load('compressed_final_data/copulation_segmented_train_label.npz')['data']

# %%
print('Number of trajectories:', X.shape[0])
print('Number of trajectories with copulation:', sum(y)[0])
# Out:
# Number of trajectories: 13303
# Number of trajectories with copulation: 7640

# %%
# Remove any trajectory with a nan for any fly in either x or y position
mask = np.any(np.isnan(X), axis=1)
mask = np.all(np.equal(mask, 0), axis=1)
X = X[mask]
y = y[mask]

# %%
print('Number of trajectories after processing:', X.shape[0])
print('Number of trajectories with copulation after processing:', sum(y)[0])
# Out:
# Number of trajectories after processing: 13303
# Number of trajectories with copulation after processing: 7640

# %%
# # Split the data into a train and test set
# X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.1)

# %%
# Split the train set into a train set and a validation set
# X_train, X_val, y_train, y_val = train_test_split(X_train, y_train, test_size=0.1)

# %%
X_train_1, X_train_2, y_train_1, y_train_2 = train_test_split(X, y, test_size=0.5, shuffle=False)

# %%
# Training 5 models for labelling (trains on 50% of the data)
for i in range(10):
    seed(i)
    set_random_seed(i+5)
    if i in [0,1,2,3,4]:
        X_train, y_train = X_train_1, y_train_1
    else:
        X_train, y_train = X_train_2, y_train_2
    model = Sequential()
    model.add(Conv1D(filters=32, kernel_size=3, padding='same', activation='relu'))
    model.add(MaxPooling1D(pool_size=2))
    model.add(Dropout(0.2))
    model.add(LSTM(10, input_shape=(100,4), return_sequences=True))
    model.add(SpatialDropout1D(0.2))
    model.add(LSTM(5, input_shape=(100,4)))
    model.add(Dense(2, activation='sigmoid'))
    model.compile(loss='binary_crossentropy', optimizer='adam', metrics=['accuracy'])
    model.fit(X_train, y_train, epochs=10, batch_size=128)
    print(model.summary())
    name = "classifier_" + str(i) + ".h5"
    model.save(name)
# Out:
# Epoch 1/10
# 6651/6651 [==============================] - 4s 619us/step - loss: 0.6121 - acc: 0.7484
# Epoch 2/10
# 6651/6651 [==============================] - 3s 470us/step - loss: 0.4961 - acc: 0.7924
# Epoch 3/10
# 6651/6651 [==============================] - 5s 752us/step - loss: 0.3993 - acc: 0.8553
# Epoch 4/10
# 6651/6651 [==============================] - 6s 951us/step - loss: 0.3173 - acc: 0.9117
# Epoch 5/10
# 6651/6651 [==============================] - 6s 929us/step - loss: 0.2534 - acc: 0.9372
# Epoch 6/10
# 6651/6651 [==============================] - 7s 1ms/step - loss: 0.2034 - acc: 0.9594
# Epoch 7/10
# 6651/6651 [==============================] - 6s 940us/step - loss: 0.1713 - acc: 0.9690
# Epoch 8/10
# 6651/6651 [==============================] - 6s 912us/step - loss: 0.1426 - acc: 0.9775
# Epoch 9/10
# 6651/6651 [==============================] - 3s 495us/step - loss: 0.1277 - acc: 0.9815
# Epoch 10/10
# 6651/6651 [==============================] - 3s 501us/step - loss: 0.1151 - acc: 0.9843
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv1d_2 (Conv1D)            (None, 100, 32)           416
# _________________________________________________________________
# max_pooling1d_2 (MaxPooling1 (None, 50, 32)            0
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 50, 32)            0
# _________________________________________________________________
# lstm_3 (LSTM)                (None, 50, 10)            1720
# _________________________________________________________________
# spatial_dropout1d_2 (Spatial (None, 50, 10)            0
# _________________________________________________________________
# lstm_4 (LSTM)                (None, 5)                 320
# _________________________________________________________________
# dense_2 (Dense)              (None, 2)                 12
# =================================================================
# Total params: 2,468
# Trainable params: 2,468
# Non-trainable params: 0
# _________________________________________________________________
# None
# Epoch 1/10
# 6651/6651 [==============================] - 5s 739us/step - loss: 0.5841 - acc: 0.7621
# Epoch 2/10
# 6651/6651 [==============================] - 3s 472us/step - loss: 0.4727 - acc: 0.7865
# Epoch 3/10
# 6651/6651 [==============================] - 3s 475us/step - loss: 0.4145 - acc: 0.7876
# Epoch 4/10
# 6651/6651 [==============================] - 3s 511us/step - loss: 0.3886 - acc: 0.7889
# Epoch 5/10
# 6651/6651 [==============================] - 6s 927us/step - loss: 0.3752 - acc: 0.7903
# Epoch 6/10
# 6651/6651 [==============================] - 6s 907us/step - loss: 0.3599 - acc: 0.8277
# Epoch 7/10
# 6651/6651 [==============================] - 6s 912us/step - loss: 0.3420 - acc: 0.8576
# Epoch 8/10
# 6651/6651 [==============================] - 6s 941us/step - loss: 0.3253 - acc: 0.8687
# Epoch 9/10
# 6651/6651 [==============================] - 6s 914us/step - loss: 0.3113 - acc: 0.8781
# Epoch 10/10
# 6651/6651 [==============================] - 6s 839us/step - loss: 0.3031 - acc: 0.8769
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv1d_3 (Conv1D)            (None, 100, 32)           416
# _________________________________________________________________
# max_pooling1d_3 (MaxPooling1 (None, 50, 32)            0
# _________________________________________________________________
# dropout_3 (Dropout)          (None, 50, 32)            0
# _________________________________________________________________
# lstm_5 (LSTM)                (None, 50, 10)            1720
# _________________________________________________________________
# spatial_dropout1d_3 (Spatial (None, 50, 10)            0
# _________________________________________________________________
# lstm_6 (LSTM)                (None, 5)                 320
# _________________________________________________________________
# dense_3 (Dense)              (None, 2)                 12
# =================================================================
# Total params: 2,468
# Trainable params: 2,468
# Non-trainable params: 0
# _________________________________________________________________
# None
# Epoch 1/10
# 6651/6651 [==============================] - 4s 676us/step - loss: 0.5963 - acc: 0.7129
# Epoch 2/10
# 6651/6651 [==============================] - 3s 471us/step - loss: 0.4867 - acc: 0.7866
# Epoch 3/10
# 6651/6651 [==============================] - 3s 493us/step - loss: 0.4305 - acc: 0.7939
# Epoch 4/10
# 6651/6651 [==============================] - 3s 506us/step - loss: 0.3688 - acc: 0.8587
# Epoch 5/10
# 6651/6651 [==============================] - 3s 515us/step - loss: 0.2949 - acc: 0.9187
# Epoch 6/10
# 6651/6651 [==============================] - 3s 518us/step - loss: 0.2492 - acc: 0.9410
# Epoch 7/10
# 6651/6651 [==============================] - 3s 521us/step - loss: 0.2034 - acc: 0.9627
# Epoch 8/10
# 6651/6651 [==============================] - 4s 527us/step - loss: 0.1760 - acc: 0.9684
# Epoch 9/10
# 6651/6651 [==============================] - 4s 531us/step - loss: 0.1467 - acc: 0.9792
# Epoch 10/10
# 6651/6651 [==============================] - 4s 538us/step - loss: 0.1288 - acc: 0.9835
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv1d_4 (Conv1D)            (None, 100, 32)           416
# _________________________________________________________________
# max_pooling1d_4 (MaxPooling1 (None, 50, 32)            0
# _________________________________________________________________
# dropout_4 (Dropout)          (None, 50, 32)            0
# _________________________________________________________________
# lstm_7 (LSTM)                (None, 50, 10)            1720
# _________________________________________________________________
# spatial_dropout1d_4 (Spatial (None, 50, 10)            0
# _________________________________________________________________
# lstm_8 (LSTM)                (None, 5)                 320
# _________________________________________________________________
# dense_4 (Dense)              (None, 2)                 12
# =================================================================
# Total params: 2,468
# Trainable params: 2,468
# Non-trainable params: 0
# _________________________________________________________________
# None
# Epoch 1/10
# 6651/6651 [==============================] - 5s 739us/step - loss: 0.5666 - acc: 0.7534
# Epoch 2/10
# 6651/6651 [==============================] - 4s 526us/step - loss: 0.4405 - acc: 0.7885
# Epoch 3/10
# 6651/6651 [==============================] - 4s 549us/step - loss: 0.3808 - acc: 0.8212
# Epoch 4/10
# 6651/6651 [==============================] - 4s 557us/step - loss: 0.3315 - acc: 0.8890
# Epoch 5/10
# 6651/6651 [==============================] - 4s 584us/step - loss: 0.3058 - acc: 0.9032
# Epoch 6/10
# 6651/6651 [==============================] - 4s 610us/step - loss: 0.2722 - acc: 0.9280
# Epoch 7/10
# 6651/6651 [==============================] - 4s 634us/step - loss: 0.2429 - acc: 0.9465
# Epoch 8/10
# 6651/6651 [==============================] - 4s 639us/step - loss: 0.2313 - acc: 0.9438
# Epoch 9/10
# 6651/6651 [==============================] - 4s 635us/step - loss: 0.1982 - acc: 0.9632
# Epoch 10/10
# 6651/6651 [==============================] - 4s 639us/step - loss: 0.1735 - acc: 0.9753
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv1d_5 (Conv1D)            (None, 100, 32)           416
# _________________________________________________________________
# max_pooling1d_5 (MaxPooling1 (None, 50, 32)            0
# _________________________________________________________________
# dropout_5 (Dropout)          (None, 50, 32)            0
# _________________________________________________________________
# lstm_9 (LSTM)                (None, 50, 10)            1720
# _________________________________________________________________
# spatial_dropout1d_5 (Spatial (None, 50, 10)            0
# _________________________________________________________________
# lstm_10 (LSTM)               (None, 5)                 320
# _________________________________________________________________
# dense_5 (Dense)              (None, 2)                 12
# =================================================================
# Total params: 2,468
# Trainable params: 2,468
# Non-trainable params: 0
# _________________________________________________________________
# None
# Epoch 1/10
# 6651/6651 [==============================] - 5s 810us/step - loss: 0.5786 - acc: 0.7530
# Epoch 2/10
# 6651/6651 [==============================] - 4s 562us/step - loss: 0.4716 - acc: 0.7867
# Epoch 3/10
# 6651/6651 [==============================] - 4s 605us/step - loss: 0.4119 - acc: 0.7867
# Epoch 4/10
# 6651/6651 [==============================] - 4s 630us/step - loss: 0.3796 - acc: 0.7867
# Epoch 5/10
# 6651/6651 [==============================] - 4s 655us/step - loss: 0.3647 - acc: 0.7867
# Epoch 6/10
# 6651/6651 [==============================] - 4s 661us/step - loss: 0.3578 - acc: 0.7867
# Epoch 7/10
# 6651/6651 [==============================] - 4s 661us/step - loss: 0.3544 - acc: 0.7867
# Epoch 8/10
# 6651/6651 [==============================] - 4s 668us/step - loss: 0.3487 - acc: 0.7994
# Epoch 9/10
# 6651/6651 [==============================] - 4s 660us/step - loss: 0.3355 - acc: 0.8392
# Epoch 10/10
# 6651/6651 [==============================] - 4s 655us/step - loss: 0.3243 - acc: 0.8600
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv1d_6 (Conv1D)            (None, 100, 32)           416
# _________________________________________________________________
# max_pooling1d_6 (MaxPooling1 (None, 50, 32)            0
# _________________________________________________________________
# dropout_6 (Dropout)          (None, 50, 32)            0
# _________________________________________________________________
# lstm_11 (LSTM)               (None, 50, 10)            1720
# _________________________________________________________________
# spatial_dropout1d_6 (Spatial (None, 50, 10)            0
# _________________________________________________________________
# lstm_12 (LSTM)               (None, 5)                 320
# _________________________________________________________________
# dense_6 (Dense)              (None, 2)                 12
# =================================================================
# Total params: 2,468
# Trainable params: 2,468
# Non-trainable params: 0
# _________________________________________________________________
# None
# Epoch 1/10
# 6652/6652 [==============================] - 6s 847us/step - loss: 0.5897 - acc: 0.7064
# Epoch 2/10
# 6652/6652 [==============================] - 4s 579us/step - loss: 0.4955 - acc: 0.7433
# Epoch 3/10
# 6652/6652 [==============================] - 4s 623us/step - loss: 0.4276 - acc: 0.7926
# Epoch 4/10
# 6652/6652 [==============================] - 4s 660us/step - loss: 0.3896 - acc: 0.8269
# Epoch 5/10
# 6652/6652 [==============================] - 4s 676us/step - loss: 0.3686 - acc: 0.8252
# Epoch 6/10
# 6652/6652 [==============================] - 5s 686us/step - loss: 0.3433 - acc: 0.8483
# Epoch 7/10
# 6652/6652 [==============================] - 5s 686us/step - loss: 0.3356 - acc: 0.8431
# Epoch 8/10
# 6652/6652 [==============================] - 5s 703us/step - loss: 0.3018 - acc: 0.8794
# Epoch 9/10
# 6652/6652 [==============================] - 5s 721us/step - loss: 0.2561 - acc: 0.9170
# Epoch 10/10
# 6652/6652 [==============================] - 5s 744us/step - loss: 0.2471 - acc: 0.9175
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv1d_7 (Conv1D)            (None, 100, 32)           416
# _________________________________________________________________
# max_pooling1d_7 (MaxPooling1 (None, 50, 32)            0
# _________________________________________________________________
# dropout_7 (Dropout)          (None, 50, 32)            0
# _________________________________________________________________
# lstm_13 (LSTM)               (None, 50, 10)            1720
# _________________________________________________________________
# spatial_dropout1d_7 (Spatial (None, 50, 10)            0
# _________________________________________________________________
# lstm_14 (LSTM)               (None, 5)                 320
# _________________________________________________________________
# dense_7 (Dense)              (None, 2)                 12
# =================================================================
# Total params: 2,468
# Trainable params: 2,468
# Non-trainable params: 0
# _________________________________________________________________
# None
# Epoch 1/10
# 6652/6652 [==============================] - 6s 946us/step - loss: 0.5221 - acc: 0.8157
# Epoch 2/10
# 6652/6652 [==============================] - 4s 624us/step - loss: 0.4357 - acc: 0.8674
# Epoch 3/10
# 6652/6652 [==============================] - 4s 672us/step - loss: 0.3869 - acc: 0.8699
# Epoch 4/10
# 6652/6652 [==============================] - 5s 692us/step - loss: 0.3371 - acc: 0.8903
# Epoch 5/10
# 6652/6652 [==============================] - 5s 715us/step - loss: 0.3565 - acc: 0.8510
# Epoch 6/10
# 6652/6652 [==============================] - 5s 717us/step - loss: 0.3098 - acc: 0.8912
# Epoch 7/10
# 6652/6652 [==============================] - 5s 719us/step - loss: 0.2794 - acc: 0.9090
# Epoch 8/10
# 6652/6652 [==============================] - 5s 712us/step - loss: 0.2794 - acc: 0.9000
# Epoch 9/10
# 6652/6652 [==============================] - 5s 732us/step - loss: 0.2592 - acc: 0.9134
# Epoch 10/10
# 6652/6652 [==============================] - 5s 766us/step - loss: 0.2496 - acc: 0.9175
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv1d_8 (Conv1D)            (None, 100, 32)           416
# _________________________________________________________________
# max_pooling1d_8 (MaxPooling1 (None, 50, 32)            0
# _________________________________________________________________
# dropout_8 (Dropout)          (None, 50, 32)            0
# _________________________________________________________________
# lstm_15 (LSTM)               (None, 50, 10)            1720
# _________________________________________________________________
# spatial_dropout1d_8 (Spatial (None, 50, 10)            0
# _________________________________________________________________
# lstm_16 (LSTM)               (None, 5)                 320
# _________________________________________________________________
# dense_8 (Dense)              (None, 2)                 12
# =================================================================
# Total params: 2,468
# Trainable params: 2,468
# Non-trainable params: 0
# _________________________________________________________________
# None
# Epoch 1/10
# 6652/6652 [==============================] - 6s 968us/step - loss: 0.5609 - acc: 0.7560
# Epoch 2/10
# 6652/6652 [==============================] - 4s 630us/step - loss: 0.4527 - acc: 0.7870
# Epoch 3/10
# 6652/6652 [==============================] - 5s 678us/step - loss: 0.4018 - acc: 0.7874
# Epoch 4/10
# 6652/6652 [==============================] - 5s 703us/step - loss: 0.3831 - acc: 0.7873
# Epoch 5/10
# 6652/6652 [==============================] - 5s 713us/step - loss: 0.3725 - acc: 0.7878
# Epoch 6/10
# 6652/6652 [==============================] - 5s 753us/step - loss: 0.3668 - acc: 0.7879
# Epoch 7/10
# 6652/6652 [==============================] - 5s 754us/step - loss: 0.3631 - acc: 0.7872
# Epoch 8/10
# 6652/6652 [==============================] - 5s 753us/step - loss: 0.3602 - acc: 0.7871
# Epoch 9/10
# 6652/6652 [==============================] - 5s 754us/step - loss: 0.3573 - acc: 0.7874
# Epoch 10/10
# 6652/6652 [==============================] - 5s 764us/step - loss: 0.3552 - acc: 0.7874
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv1d_9 (Conv1D)            (None, 100, 32)           416
# _________________________________________________________________
# max_pooling1d_9 (MaxPooling1 (None, 50, 32)            0
# _________________________________________________________________
# dropout_9 (Dropout)          (None, 50, 32)            0
# _________________________________________________________________
# lstm_17 (LSTM)               (None, 50, 10)            1720
# _________________________________________________________________
# spatial_dropout1d_9 (Spatial (None, 50, 10)            0
# _________________________________________________________________
# lstm_18 (LSTM)               (None, 5)                 320
# _________________________________________________________________
# dense_9 (Dense)              (None, 2)                 12
# =================================================================
# Total params: 2,468
# Trainable params: 2,468
# Non-trainable params: 0
# _________________________________________________________________
# None
# Epoch 1/10
# 6652/6652 [==============================] - 7s 1ms/step - loss: 0.6150 - acc: 0.7146
# Epoch 2/10
# 6652/6652 [==============================] - 4s 626us/step - loss: 0.5103 - acc: 0.7863
# Epoch 3/10
# 6652/6652 [==============================] - 5s 683us/step - loss: 0.4508 - acc: 0.7875
# Epoch 4/10
# 6652/6652 [==============================] - 5s 711us/step - loss: 0.4084 - acc: 0.7877
# Epoch 5/10
# 6652/6652 [==============================] - 5s 731us/step - loss: 0.3844 - acc: 0.7904
# Epoch 6/10
# 6652/6652 [==============================] - 5s 747us/step - loss: 0.3726 - acc: 0.7952
# Epoch 7/10
# 6652/6652 [==============================] - 5s 753us/step - loss: 0.3581 - acc: 0.8067
# Epoch 8/10
# 6652/6652 [==============================] - 5s 752us/step - loss: 0.3233 - acc: 0.8520
# Epoch 9/10
# 6652/6652 [==============================] - 5s 746us/step - loss: 0.2579 - acc: 0.9101
# Epoch 10/10
# 6652/6652 [==============================] - 5s 744us/step - loss: 0.2005 - acc: 0.9498
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv1d_10 (Conv1D)           (None, 100, 32)           416
# _________________________________________________________________
# max_pooling1d_10 (MaxPooling (None, 50, 32)            0
# _________________________________________________________________
# dropout_10 (Dropout)         (None, 50, 32)            0
# _________________________________________________________________
# lstm_19 (LSTM)               (None, 50, 10)            1720
# _________________________________________________________________
# spatial_dropout1d_10 (Spatia (None, 50, 10)            0
# _________________________________________________________________
# lstm_20 (LSTM)               (None, 5)                 320
# _________________________________________________________________
# dense_10 (Dense)             (None, 2)                 12
# =================================================================
# Total params: 2,468
# Trainable params: 2,468
# Non-trainable params: 0
# _________________________________________________________________
# None
# Epoch 1/10
# 6652/6652 [==============================] - 7s 1ms/step - loss: 0.6298 - acc: 0.6334
# Epoch 2/10
# 6652/6652 [==============================] - 4s 629us/step - loss: 0.4795 - acc: 0.7218
# Epoch 3/10
# 6652/6652 [==============================] - 5s 687us/step - loss: 0.4148 - acc: 0.7574
# Epoch 4/10
# 6652/6652 [==============================] - 5s 718us/step - loss: 0.3791 - acc: 0.7875
# Epoch 5/10
# 6652/6652 [==============================] - 5s 751us/step - loss: 0.3641 - acc: 0.7876
# Epoch 6/10
# 6652/6652 [==============================] - 5s 752us/step - loss: 0.3583 - acc: 0.7876
# Epoch 7/10
# 6652/6652 [==============================] - 5s 753us/step - loss: 0.3552 - acc: 0.7876
# Epoch 8/10
# 6652/6652 [==============================] - 5s 756us/step - loss: 0.3532 - acc: 0.7876
# Epoch 9/10
# 6652/6652 [==============================] - 5s 752us/step - loss: 0.3516 - acc: 0.7876
# Epoch 10/10
# 6652/6652 [==============================] - 5s 749us/step - loss: 0.3501 - acc: 0.7876
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv1d_11 (Conv1D)           (None, 100, 32)           416
# _________________________________________________________________
# max_pooling1d_11 (MaxPooling (None, 50, 32)            0
# _________________________________________________________________
# dropout_11 (Dropout)         (None, 50, 32)            0
# _________________________________________________________________
# lstm_21 (LSTM)               (None, 50, 10)            1720
# _________________________________________________________________
# spatial_dropout1d_11 (Spatia (None, 50, 10)            0
# _________________________________________________________________
# lstm_22 (LSTM)               (None, 5)                 320
# _________________________________________________________________
# dense_11 (Dense)             (None, 2)                 12
# =================================================================
# Total params: 2,468
# Trainable params: 2,468
# Non-trainable params: 0
# _________________________________________________________________
# None

# %%
# Predict on the test set and round predictions
y_pred = np.rint(model.predict(X_test))

# %%
# Find the correct and incorrect predictions
correct = y_pred[y_test == y_pred]
incorrect = y_pred[y_test != y_pred]

# %%
# Compute the accuracy for the model
accuracy = len(correct) /2w (len(correct) + len(incorrect))
print('Accuracy: {0:.2f}%'.format(accuracy * 100))
# Out:
# Accuracy: 98.98%

# %%
# Compute the recall for the model
true_positives = correct[correct == 1]
false_positives = incorrect[incorrect == 1]
recall = len(true_positives) / (len(false_positives) + len(true_positives))
print('Recall: {0:.4f}%'.format(recall * 100))
# Out:
# Recall: 96.8172%

# %%
# Compute the precision for the model
false_negatives = incorrect[incorrect == 0]
precision = len(true_positives) / (len(false_negatives) + len(true_positives))
print('Precision: {0:.4f}%'.format(precision * 100))
# Out:
# Precision: 99.6829%

# %%
print('Number of trajectories with copulation:', sum(y_test)[0])
print('Number of trajectories classified as copulation:', int(sum(y_pred)[0]))
# Out:
# Number of trajectories with copulation: 946
# Number of trajectories classified as copulation: 974
